# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**    **Maria Beatriz Oliveira de Souza**
#
# **Turma:**  **2A TI**
#
# **Tema Escolhido:**   **Sistema gerenciador de serviços diversos**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 1
class Servico_maria:
    def __init__(self, nome, descricao, preco):
        self.nome = nome
        self.descricao = descricao
        self.preco = preco
    def exibir_dados(self):
        print(f'Nome: {self.nome}')
        print(f'Descriçao: {self.descricao}')
        print(f'Preço: R${self.preco:.2}')

servico1 = Servico_maria('Limpeza residencial', 'Limpeza completa de casas e apartamentos', 150.00)
servico2 = Servico_maria('Manutenção de PC', 'Formatação, limpeza e instalação de softwares', 200.00)

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2
class Servico_maria:
    def __init__(self, nome, descricao, preco):
        self.nome = nome
        self.descricao = descricao
        self.preco = preco
    def exibir_dados(self):
        print(f'Nome: {self.nome}')
        print(f'Descriçao: {self.descricao}')
        print(f'Preço: R${self.preco:.2f}')

    def aplicar_desconto(self, percentual):
        desconto = (self.preco * percentual) / 100
        self.preco -= desconto
        print(f"Desconto de {percentual}% aplicado. Novo preço: R${self.preco: .2f}")
    
    def atualizar_preco(self, novo_preco):
        self.preco = novo_preco
        print(f"Preço atualizado para: R${self.preco: .2f}")

class ServicoPremium_maria(Servico_maria):
  def __init__(self, nome, descricao, preco, taxa_extra):
    super().__init__(nome, descricao, preco)
    self.taxa_extra = taxa_extra

  def aplicar_taxa_extra(self):
    self.preco += self.taxa_extra
    print(f'Taxa extra aplicada. Novo preço: R${self.preco: .2f}')

  def exibir_dados(self):
    super().exibir_dados()
    print(f'Taxa extra (premium): R${self.taxa_extra: .2f}')
  

servico1 = Servico_maria('Limpeza residencial', 'Limpeza completa de casas e apartamentos', 150.00)
servico2 = Servico_maria('Manutenção de PC', 'Formatação, limpeza e instalação de softwares', 200.00) 

print("Antes de aplicar ações: ")
servico1.exibir_dados()
servico2.exibir_dados()

servico1.aplicar_desconto(10)
servico2.atualizar_preco(180.00)

print("\nApós as ações:")
servico1.exibir_dados()
servico2.exibir_dados()

print('\nServiço Premium:')
premium = ServicoPremium_maria('Limpeza pós-obra', 'Limpeza pesada após reforma', 300.00, 50.00)
premium.exibir_dados()
premium.aplicar_taxa_extra()
premium.exibir_dados()

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3
class Servico_maria:
    def __init__(self, nome, descricao, preco):
        self.nome = nome
        self.descricao = descricao
        self.preco = preco
        self.__codigo_interno = str(uuid.uuid4())
    def exibir_dados(self):
        print(f'Nome: {self.nome}')
        print(f'Descriçao: {self.descricao}')
        print(f'Preço: R${self.preco:.2f}')

    def aplicar_desconto(self, percentual):
        desconto = (self.preco * percentual) / 100
        self.preco -= desconto
        print(f"Desconto de {percentual}% aplicado. Novo preço: R${self.preco: .2f}")
    
    def atualizar_preco(self, novo_preco):
        self.preco = novo_preco
        print(f"Preço atualizado para: R${self.preco: .2f}")

    def get_codigo_interno(self):
        return self.__codigo_interno

    def set_codigo_interno(self, novo_codigo):
        self.__codigo_interno = novo_codigo

class ServicoPremium_maria(Servico_maria):
  def __init__(self, nome, descricao, preco, taxa_extra):
    super().__init__(nome, descricao, preco)
    self.taxa_extra = taxa_extra

  def aplicar_taxa_extra(self):
    self.preco += self.taxa_extra
    print(f'Taxa extra aplicada. Novo preço: R${self.preco: .2f}')

  def exibir_dados(self):
    super().exibir_dados()
    print(f'Taxa extra (premium): R${self.taxa_extra: .2f}')
  

servico1 = Servico_maria('Limpeza residencial', 'Limpeza completa de casas e apartamentos', 150.00)
servico2 = Servico_maria('Manutenção de PC', 'Formatação, limpeza e instalação de softwares', 200.00) 

print("Antes de aplicar ações: ")
servico1.exibir_dados()
servico2.exibir_dados()

servico1.aplicar_desconto(10)
servico2.atualizar_preco(180.00)

print("\nApós as ações:")
servico1.exibir_dados()
servico2.exibir_dados()

print('\nServiço Premium:')
premium = ServicoPremium_maria('Limpeza pós-obra', 'Limpeza pesada após reforma', 300.00, 50.00)
premium.exibir_dados()
premium.aplicar_taxa_extra()
premium.exibir_dados()

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import mysql.connector
import uuid

class DBManager:
    def __init__(self):
        self.conn = mysql.connector.connect(
            host='localhost',
            user='root',
            database='servicos_db'
        )
        self.cursor = self.conn.cursor()

    def inserir_servico(self, servico):
        sql = "INSERT INTO servicos (id, nome, descricao, preco, taxa_extra) VALUES (%s, %s, %s, %s, %s)"
        valores = (servico.get_codigo_interno(), servico.nome, servico.descricao, servico.preco,
                   getattr(servico, 'taxa_extra', None))
        self.cursor.execute(sql, valores)
        self.conn.commit()
        print(f"Serviço '{servico.nome}' inserido no banco de dados.")

    def fechar_conexao(self):
        self.cursor.close()
        self.conn.close()

class Servico_maria:
    def __init__(self, nome, descricao, preco):
        self.nome = nome
        self.descricao = descricao
        self.preco = preco
        self.__codigo_interno = str(uuid.uuid4())

    def exibir_dados(self):
        print(f'Nome: {self.nome}')
        print(f'Descriçao: {self.descricao}')
        print(f'Preço: R${self.preco:.2f}')

    def aplicar_desconto(self, percentual):
        desconto = (self.preco * percentual) / 100
        self.preco -= desconto
        print(f"Desconto de {percentual}% aplicado. Novo preço: R${self.preco: .2f}")

    def atualizar_preco(self, novo_preco):
        self.preco = novo_preco
        print(f"Preço atualizado para: R${self.preco: .2f}")

    def get_codigo_interno(self):
        return self.__codigo_interno

     def set_codigo_interno(self, novo_codigo):
        self.__codigo_interno = novo_codigo

class ServicoPremium_maria(Servico_maria):
    def __init__(self, nome, descricao, preco, taxa_extra):
        super().__init__(nome, descricao, preco)
        self.taxa_extra = taxa_extra

    def aplicar_taxa_extra(self):
        self.preco += self.taxa_extra
        print(f'Taxa extra aplicada. Novo preço: R${self.preco: .2f}')

    def exibir_dados(self):
        super().exibir_dados()
        print(f'Taxa extra (premium): R${self.taxa_extra: .2f}')


# Usando o sistema com banco
db = DBManager()

servico1 = Servico_maria('Limpeza residencial', 'Limpeza completa de casas e apartamentos', 150.00)
servico2 = Servico_maria('Manutenção de PC', 'Formatação, limpeza e instalação de softwares', 200.00)
premium = ServicoPremium_maria('Limpeza pós-obra', 'Limpeza pesada após reforma', 300.00, 50.00)

# Inserindo no banco
db.inserir_servico(servico1)
db.inserir_servico(servico2)
db.inserir_servico(premium)

db.fechar_conexao()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 5
import mysql.connector  # Importa biblioteca para conectar ao MySQL
import uuid  # Importa biblioteca para gerar IDs únicos universais

# Classe que gerencia conexão e operações no banco de dados
class DBManager:
    def __init__(self):
        # Estabelece conexão com banco MySQL usando host, usuário e banco específicos
        self.conn = mysql.connector.connect(
            host='localhost',
            user='root',
            database='servicos_db'
        )
        self.cursor = self.conn.cursor()  # Cria cursor para executar comandos SQL

    # Método para inserir um serviço na tabela 'servicos'
    def inserir_servico(self, servico):
        sql = "INSERT INTO servicos (id, nome, descricao, preco, taxa_extra) VALUES (%s, %s, %s, %s, %s)"
        # Pega os valores do serviço, incluindo taxa_extra se existir, senão None
        valores = (servico.get_codigo_interno(), servico.nome, servico.descricao, servico.preco,
                   getattr(servico, 'taxa_extra', None))
        self.cursor.execute(sql, valores)  # Executa o comando SQL com os valores fornecidos
        self.conn.commit()  # Confirma a operação no banco
        print(f"Serviço '{servico.nome}' inserido no banco de dados.")  # Confirmação na tela

    # Método para fechar conexão e cursor do banco
    def fechar_conexao(self):
        self.cursor.close()  # Fecha o cursor
        self.conn.close()    # Fecha a conexão com o banco


# Classe que representa um serviço comum
class Servico_maria:
    def __init__(self, nome, descricao, preco):
        self.nome = nome  # Nome do serviço
        self.descricao = descricao  # Descrição do serviço
        self.preco = preco  # Preço do serviço
        self.__codigo_interno = str(uuid.uuid4())  # Código interno único, privado

    # Exibe os dados do serviço formatados
    def exibir_dados(self):
        print(f'Nome: {self.nome}')
        print(f'Descriçao: {self.descricao}')
        print(f'Preço: R${self.preco:.2f}')

    # Aplica desconto percentual no preço e atualiza valor
    def aplicar_desconto(self, percentual):
        desconto = (self.preco * percentual) / 100
        self.preco -= desconto
        print(f"Desconto de {percentual}% aplicado. Novo preço: R${self.preco: .2f}")

    # Atualiza o preço para um novo valor
    def atualizar_preco(self, novo_preco):
        self.preco = novo_preco
        print(f"Preço atualizado para: R${self.preco: .2f}")

    # Retorna o código interno privado
    def get_codigo_interno(self):
        return self.__codigo_interno

    # Atualiza o código interno (método setter)
    def set_codigo_interno(self, novo_codigo):
        self.__codigo_interno = novo_codigo


# Classe que representa um serviço premium, herda de Servico_maria
class ServicoPremium_maria(Servico_maria):
    def __init__(self, nome, descricao, preco, taxa_extra):
        super().__init__(nome, descricao, preco)  # Chama o construtor da classe base
        self.taxa_extra = taxa_extra  # Define taxa extra para serviço premium

    # Aplica taxa extra ao preço do serviço
    def aplicar_taxa_extra(self):
        self.preco += self.taxa_extra
        print(f'Taxa extra aplicada. Novo preço: R${self.preco: .2f}')

    # Exibe dados do serviço premium, incluindo taxa extra
    def exibir_dados(self):
        super().exibir_dados()  # Exibe dados do serviço base
        print(f'Taxa extra (premium): R${self.taxa_extra: .2f}')


# Criando instância do gerenciador do banco
db = DBManager()

# Criando serviços
servico1 = Servico_maria('Limpeza residencial', 'Limpeza completa de casas e apartamentos', 150.00)
servico2 = Servico_maria('Manutenção de PC', 'Formatação, limpeza e instalação de softwares', 200.00)
servico3 = Servico_maria('Passeio com cachorro', 'Passear, alimentar e dar agua', 30.00)
servico4 = Servico_maria('Reparos automotivos', 'Reparos gerais de automóveis', 250.00)
premium = ServicoPremium_maria('Limpeza pós-obra', 'Limpeza pesada após reforma', 300.00, 50.00)

# Inserindo serviços no banco de dados
db.inserir_servico(servico1)
db.inserir_servico(servico2)
db.inserir_servico(servico3)
db.inserir_servico(premium)

# Fechando conexão com banco
db.fechar_conexao()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\network.py:795, in MySQLTCPSocket.open_connection(self)
#     794     self.sock.settimeout(self._connection_timeout)
# --> 795     self.sock.connect(sockaddr)
#     796 except (socket.timeout, TimeoutError) as err:
#
# ConnectionRefusedError: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In[2], line 84
#      80         print(f'Taxa extra (premium): R${self.taxa_extra: .2f}')
#      83 # Criando instância do gerenciador do banco
# ---> 84 db = DBManager()
#      86 # Criando serviços
#      87 servico1 = Servico_maria('Limpeza residencial', 'Limpeza completa de casas e apartamentos', 150.00)
#
# Cell In[2], line 9, in DBManager.__init__(self)
#       7 def __init__(self):
#       8     # Estabelece conexão com banco MySQL usando host, usuário e banco específicos
# ----> 9     self.conn = mysql.connector.connect(
#      10         host='localhost',
#      11         user='root',
#      12         database='servicos_db'
#      13     )
#      14     self.cursor = self.conn.cursor()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\pooling.py:323, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
#     322     return CMySQLConnection(*args, **kwargs)
# --> 323 return MySQLConnection(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:185, in MySQLConnection.__init__(self, **kwargs)
#     183 if kwargs:
#     184     try:
# --> 185         self.connect(**kwargs)
#     186     except Exception:
#     187         # Tidy-up underlying socket on failure
#     188         self.close()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\abstracts.py:1605, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1602     self.config(**kwargs)
#    1604 self.disconnect()
# -> 1605 self._open_connection()
#    1607 charset, collation = (
#    1608     kwargs.pop("charset", None),
#    1609     kwargs.pop("collation", None),
#    1610 )
#    1611 if charset or collation:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:411, in MySQLConnection._open_connection(self)
#     406     if isinstance(err, (ReadTimeoutError, WriteTimeoutError)):
#     407         raise ConnectionTimeoutError(
#     408             errno=err.errno,
#     409             msg=err.msg,
#     410         ) from err
# --> 411     raise err
#     412 finally:
#     413     # as the connection is established, set back the read
#     414     # and write timeouts to the original value
#     415     self.read_timeout = stored_read_timeout
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:382, in MySQLConnection._open_connection(self)
#     380 self._socket = self._get_connection()
#     381 try:
# --> 382     self._socket.open_connection()
#     384     # do initial handshake
#     385     self._do_handshake()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\network.py:806, in MySQLTCPSocket.open_connection(self)
#     797     raise ConnectionTimeoutError(
#     798         errno=2003,
#     799         values=(
#    (...)
#     803         ),
#     804     ) from err
#     805 except IOError as err:
# --> 806     raise InterfaceError(
#     807         errno=2003,
#     808         values=(self.server_host, self.server_port, _strioerror(err)),
#     809     ) from err
#     810 except Exception as err:
#     811     raise InterfaceError(str(err)) from err
#
# InterfaceError: 2003: Can't connect to MySQL server on 'localhost:3306' (Errno 10061: Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente)

# %%
db.inserir_servico(servico4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 servico4 = Servico_maria('Reparos automotivos', 'Reparos gerais de automóveis', 250.00)
#       2 db.inserir_servico(servico4)
#
# NameError: name 'Servico_maria' is not defined
