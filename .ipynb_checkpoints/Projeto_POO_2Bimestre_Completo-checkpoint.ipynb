# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**    **Maria Beatriz Oliveira de Souza**
#
# **Turma:**  **2A TI**
#
# **Tema Escolhido:**   **Sistema gerenciador de serviços diversos**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 1
class Servico_maria:
    def __init__(self, nome, descricao, preco):
        self.nome = nome
        self.descricao = descricao
        self.preco = preco
    def exibir_dados(self):
        print(f'Nome: {self.nome}')
        print(f'Descriçao: {self.descricao}')
        print(f'Preço: R${self.preco:.2}')

servico1 = Servico_maria('Limpeza residencial', 'Limpeza completa de casas e apartamentos', 150.00)
servico2 = Servico_maria('Manutenção de PC', 'Formatação, limpeza e instalação de softwares', 200.00)

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2
class Servico_maria:
    def __init__(self, nome, descricao, preco):
        self.nome = nome
        self.descricao = descricao
        self.preco = preco
    def exibir_dados(self):
        print(f'Nome: {self.nome}')
        print(f'Descriçao: {self.descricao}')
        print(f'Preço: R${self.preco:.2f}')

    def aplicar_desconto(self, percentual):
        desconto = (self.preco * percentual) / 100
        self.preco -= desconto
        print(f"Desconto de {percentual}% aplicado. Novo preço: R${self.preco: .2f}")
    
    def atualizar_preco(self, novo_preco):
        self.preco = novo_preco
        print(f"Preço atualizado para: R${self.preco: .2f}")

class ServicoPremium_maria(Servico_maria):
  def __init__(self, nome, descricao, preco, taxa_extra):
    super().__init__(nome, descricao, preco)
    self.taxa_extra = taxa_extra

  def aplicar_taxa_extra(self):
    self.preco += self.taxa_extra
    print(f'Taxa extra aplicada. Novo preço: R${self.preco: .2f}')

  def exibir_dados(self):
    super().exibir_dados()
    print(f'Taxa extra (premium): R${self.taxa_extra: .2f}')
  

servico1 = Servico_maria('Limpeza residencial', 'Limpeza completa de casas e apartamentos', 150.00)
servico2 = Servico_maria('Manutenção de PC', 'Formatação, limpeza e instalação de softwares', 200.00) 

print("Antes de aplicar ações: ")
servico1.exibir_dados()
servico2.exibir_dados()

servico1.aplicar_desconto(10)
servico2.atualizar_preco(180.00)

print("\nApós as ações:")
servico1.exibir_dados()
servico2.exibir_dados()

print('\nServiço Premium:')
premium = ServicoPremium_maria('Limpeza pós-obra', 'Limpeza pesada após reforma', 300.00, 50.00)
premium.exibir_dados()
premium.aplicar_taxa_extra()
premium.exibir_dados()

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3
class Servico_maria:
    def __init__(self, nome, descricao, preco):
        self.nome = nome
        self.descricao = descricao
        self.preco = preco
        self.__codigo_interno = str(uuid.uuid4())
    def exibir_dados(self):
        print(f'Nome: {self.nome}')
        print(f'Descriçao: {self.descricao}')
        print(f'Preço: R${self.preco:.2f}')

    def aplicar_desconto(self, percentual):
        desconto = (self.preco * percentual) / 100
        self.preco -= desconto
        print(f"Desconto de {percentual}% aplicado. Novo preço: R${self.preco: .2f}")
    
    def atualizar_preco(self, novo_preco):
        self.preco = novo_preco
        print(f"Preço atualizado para: R${self.preco: .2f}")

    def get_codigo_interno(self):
        return self.__codigo_interno

    def set_codigo_interno(self, novo_codigo):
        self.__codigo_interno = novo_codigo

class ServicoPremium_maria(Servico_maria):
  def __init__(self, nome, descricao, preco, taxa_extra):
    super().__init__(nome, descricao, preco)
    self.taxa_extra = taxa_extra

  def aplicar_taxa_extra(self):
    self.preco += self.taxa_extra
    print(f'Taxa extra aplicada. Novo preço: R${self.preco: .2f}')

  def exibir_dados(self):
    super().exibir_dados()
    print(f'Taxa extra (premium): R${self.taxa_extra: .2f}')
  

servico1 = Servico_maria('Limpeza residencial', 'Limpeza completa de casas e apartamentos', 150.00)
servico2 = Servico_maria('Manutenção de PC', 'Formatação, limpeza e instalação de softwares', 200.00) 

print("Antes de aplicar ações: ")
servico1.exibir_dados()
servico2.exibir_dados()

servico1.aplicar_desconto(10)
servico2.atualizar_preco(180.00)

print("\nApós as ações:")
servico1.exibir_dados()
servico2.exibir_dados()

print('\nServiço Premium:')
premium = ServicoPremium_maria('Limpeza pós-obra', 'Limpeza pesada após reforma', 300.00, 50.00)
premium.exibir_dados()
premium.aplicar_taxa_extra()
premium.exibir_dados()

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import mysql.connector
import uuid

class DBManager:
    def __init__(self):
        self.conn = mysql.connector.connect(
            host='localhost',
            user='root',
            database='servicos_db'
        )
        self.cursor = self.conn.cursor()

    def inserir_servico(self, servico):
        sql = "INSERT INTO servicos (id, nome, descricao, preco, taxa_extra) VALUES (%s, %s, %s, %s, %s)"
        valores = (servico.get_codigo_interno(), servico.nome, servico.descricao, servico.preco,
                   getattr(servico, 'taxa_extra', None))
        self.cursor.execute(sql, valores)
        self.conn.commit()
        print(f"Serviço '{servico.nome}' inserido no banco de dados.")

    def fechar_conexao(self):
        self.cursor.close()
        self.conn.close()

class Servico_maria:
    def __init__(self, nome, descricao, preco):
        self.nome = nome
        self.descricao = descricao
        self.preco = preco
        self.__codigo_interno = str(uuid.uuid4())

    def exibir_dados(self):
        print(f'Nome: {self.nome}')
        print(f'Descriçao: {self.descricao}')
        print(f'Preço: R${self.preco:.2f}')

    def aplicar_desconto(self, percentual):
        desconto = (self.preco * percentual) / 100
        self.preco -= desconto
        print(f"Desconto de {percentual}% aplicado. Novo preço: R${self.preco: .2f}")

    def atualizar_preco(self, novo_preco):
        self.preco = novo_preco
        print(f"Preço atualizado para: R${self.preco: .2f}")

    def get_codigo_interno(self):
        return self.__codigo_interno

     def set_codigo_interno(self, novo_codigo):
        self.__codigo_interno = novo_codigo

class ServicoPremium_maria(Servico_maria):
    def __init__(self, nome, descricao, preco, taxa_extra):
        super().__init__(nome, descricao, preco)
        self.taxa_extra = taxa_extra

    def aplicar_taxa_extra(self):
        self.preco += self.taxa_extra
        print(f'Taxa extra aplicada. Novo preço: R${self.preco: .2f}')

    def exibir_dados(self):
        super().exibir_dados()
        print(f'Taxa extra (premium): R${self.taxa_extra: .2f}')


# Usando o sistema com banco
db = DBManager()

servico1 = Servico_maria('Limpeza residencial', 'Limpeza completa de casas e apartamentos', 150.00)
servico2 = Servico_maria('Manutenção de PC', 'Formatação, limpeza e instalação de softwares', 200.00)
premium = ServicoPremium_maria('Limpeza pós-obra', 'Limpeza pesada após reforma', 300.00, 50.00)

# Inserindo no banco
db.inserir_servico(servico1)
db.inserir_servico(servico2)
db.inserir_servico(premium)

db.fechar_conexao()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import mysql.connector
import uuid

class DBManager:
    def __init__(self):
        self.conn = mysql.connector.connect(
            host='localhost',
            user='root',
            password='',  # ajuste sua senha
            database='servicos_db'
        )
        self.cursor = self.conn.cursor()

    def inserir_servico(self, servico):
        sql = "INSERT INTO servicos (id, nome, descricao, preco, taxa_extra) VALUES (%s, %s, %s, %s, %s)"
        valores = (servico.get_codigo_interno(), servico.nome, servico.descricao, servico.preco,
                   getattr(servico, 'taxa_extra', None))
        self.cursor.execute(sql, valores)
        self.conn.commit()

    def listar_servicos(self):
        self.cursor.execute("SELECT id, nome, descricao, preco, taxa_extra FROM servicos")
        return self.cursor.fetchall()

    def buscar_servico_por_id(self, id_servico):
        self.cursor.execute("SELECT id, nome, descricao, preco, taxa_extra FROM servicos WHERE id = %s", (id_servico,))
        return self.cursor.fetchone()

    def atualizar_servico(self, id_servico, nome, descricao, preco, taxa_extra):
        sql = """UPDATE servicos
                 SET nome=%s, descricao=%s, preco=%s, taxa_extra=%s
                 WHERE id=%s"""
        self.cursor.execute(sql, (nome, descricao, preco, taxa_extra, id_servico))
        self.conn.commit()

    def deletar_servico(self, id_servico):
        self.cursor.execute("DELETE FROM servicos WHERE id=%s", (id_servico,))
        self.conn.commit()

    def fechar_conexao(self):
        self.cursor.close()
        self.conn.close()

class Servico:
    def __init__(self, nome, descricao, preco, taxa_extra=None, id=None):
        self.nome = nome
        self.descricao = descricao
        self.preco = preco
        self.taxa_extra = taxa_extra
        self.__codigo_interno = id if id else str(uuid.uuid4())

    def get_codigo_interno(self):
        return self.__codigo_interno

# funções para operações (igual antes)...

def adicionar_servico(db):
    nome = input("Nome do serviço: ").strip()
    descricao = input("Descrição do serviço: ").strip()
    preco = float(input("Preço do serviço: ").strip())
    tipo = input("É serviço premium? (s/n): ").strip().lower()
    taxa_extra = None
    if tipo == 's':
        taxa_extra = float(input("Informe a taxa extra: ").strip())
    servico = Servico(nome, descricao, preco, taxa_extra)
    db.inserir_servico(servico)
    print("Serviço adicionado com sucesso!")

def listar_servicos(db):
    servicos = db.listar_servicos()
    if not servicos:
        print("Nenhum serviço cadastrado.")
        return
    print("\nLista de Serviços:")
    for i, (id_, nome, descricao, preco, taxa_extra) in enumerate(servicos, 1):
        print(f"{i}. ID: {id_}")
        print(f"   Nome: {nome}")
        print(f"   Descrição: {descricao}")
        print(f"   Preço: R${preco:.2f}")
        if taxa_extra is not None:
            print(f"   Taxa extra: R${taxa_extra:.2f}")
        print("")

def editar_servico(db):
    listar_servicos(db)
    id_servico = input("Digite o ID do serviço que quer editar: ").strip()
    servico = db.buscar_servico_por_id(id_servico)
    if not servico:
        print("Serviço não encontrado.")
        return
    print("Deixe em branco para não alterar o campo.")
    nome = input(f"Nome ({servico[1]}): ").strip() or servico[1]
    descricao = input(f"Descrição ({servico[2]}): ").strip() or servico[2]
    preco_input = input(f"Preço ({servico[3]}): ").strip()
    preco = float(preco_input) if preco_input else servico[3]
    taxa_extra_input = input(f"Taxa extra ({servico[4]}): ").strip()
    taxa_extra = float(taxa_extra_input) if taxa_extra_input else servico[4]

    db.atualizar_servico(id_servico, nome, descricao, preco, taxa_extra)
    print("Serviço atualizado com sucesso!")

def excluir_servico(db):
    listar_servicos(db)
    id_servico = input("Digite o ID do serviço que quer excluir: ").strip()
    servico = db.buscar_servico_por_id(id_servico)
    if not servico:
        print("Serviço não encontrado.")
        return
    confirma = input(f"Tem certeza que deseja excluir o serviço '{servico[1]}'? (s/n): ").strip().lower()
    if confirma == 's':
        db.deletar_servico(id_servico)
        print("Serviço excluído com sucesso!")
    else:
        print("Operação cancelada.")

def menu():
    print("""
--- Sistema de Serviços ---
1. Adicionar serviço
2. Listar serviços
3. Editar serviço
4. Excluir serviço
5. Sair
""")

# Aqui, não vamos rodar o loop infinito automático,
# mas sim deixar o controle pro usuário rodar células ou chamar funções manualmente.

# Exemplo de uso:

db = DBManager()

# Para mostrar o menu e escolher uma opção, você pode executar essa célula várias vezes:
menu()
opcao = input("Escolha uma opção: ").strip()

if opcao == '1':
    adicionar_servico(db)
elif opcao == '2':
    listar_servicos(db)
elif opcao == '3':
    editar_servico(db)
elif opcao == '4':
    excluir_servico(db)
elif opcao == '5':
    print("Fechando conexão e saindo...")
    db.fechar_conexao()
else:
    print("Opção inválida.")
# Out:
# Serviço 'Limpeza residencial' inserido no banco de dados.
# Serviço 'Manutenção de PC' inserido no banco de dados.
# Serviço 'Passeio com cachorro' inserido no banco de dados.
# Serviço 'Reparos automotivos' inserido no banco de dados.
# Serviço 'Banho e tosa' inserido no banco de dados.
# Serviço 'Limpeza pós-obra' inserido no banco de dados.
